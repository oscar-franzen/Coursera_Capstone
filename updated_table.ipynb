# %% [markdown]
# Scrape the Wikipedia table for Canadian Postal Codes and make a data frame out of it

# %%
import urllib.request

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
page = urllib.request.urlopen(url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page, "lxml")

# %%
tab = soup.find('table', class_='wikitable sortable')

# %%
foo = []

for row in tab.findAll('tr'):
    cells = row.findAll('td')
    #foo.append(cells)
    if len(cells) > 0:
        foo.append([cells[0].find(text=True).replace('\n', ''),
                    cells[1].find(text=True).replace('\n', ''),
                    cells[2].find(text=True).replace('\n', '')])

import pandas as pd
pc = pd.DataFrame(foo)

# %%
pc.columns = ['PostalCode', 'Borough', 'Neighborhood']
pc = pc[pc.Borough != 'Not assigned']

# %% [markdown]
# There are no cells with neighborhood "Not assigned"

# %%
import numpy as np
np.sum(pc.Neighborhood == 'Not assigned')

# %%
pc
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 20         M3C        North York
# 21         M4C         East York
# 22         M5C  Downtown Toronto
# 23         M6C              York
# 26         M9C         Etobicoke
# 27         M1E       Scarborough
# 30         M4E      East Toronto
# 31         M5E  Downtown Toronto
# 32         M6E              York
# 36         M1G       Scarborough
# 39         M4G         East York
# 40         M5G  Downtown Toronto
# 41         M6G  Downtown Toronto
# 45         M1H       Scarborough
# ...

# %%
pc.shape
# Out:
# (103, 3)

# %%
# !wget https://cocl.us/Geospatial_data
# Out:
# --2020-08-12 13:16:41--  https://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 169.55.161.7
# Connecting to cocl.us (cocl.us)|169.55.161.7|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-08-12 13:16:42--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.29.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.29.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-08-12 13:16:42--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# ...

# %%
d = pd.read_csv('Geospatial_data')

# %%
d.index = d.iloc[:, 0]

# %%
d = d.reindex(pc.PostalCode)

# %%
pc['Latitude'] = d.iloc[:,1].values
pc['Longitude'] = d.iloc[:,2].values

# %%
pc
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 20         M3C        North York
# 21         M4C         East York
# 22         M5C  Downtown Toronto
# 23         M6C              York
# 26         M9C         Etobicoke
# 27         M1E       Scarborough
# 30         M4E      East Toronto
# 31         M5E  Downtown Toronto
# 32         M6E              York
# 36         M1G       Scarborough
# 39         M4G         East York
# 40         M5G  Downtown Toronto
# 41         M6G  Downtown Toronto
# 45         M1H       Scarborough
# ...
