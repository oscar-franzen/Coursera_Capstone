# %% [markdown]
# # Introduction

# %% [markdown]
# Define good areas to start a restaurant in Stockholm, Sweden. Essentially, I want to define areas not saturated with restaurant options so that it would make sense to start one. In particular, I'm interested in defining areas without a Pizza place, so it would be great to find those areas missing this restaurant option.

# %% [markdown]
# # Data

# %% [markdown]
# Data will come from the Foursquare location API as well as using zip codes with longitude and latitude. The latter can be downloaded from http://download.geonames.org/export/zip/SE.zip and then filtered based on the string "Stockholm".

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Download Swedish zip codes

# %%
# !wget http://download.geonames.org/export/zip/SE.zip
# Out:
# --2020-08-13 15:15:59--  http://download.geonames.org/export/zip/SE.zip
# Resolving download.geonames.org (download.geonames.org)... 188.40.33.19
# Connecting to download.geonames.org (download.geonames.org)|188.40.33.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84322 (82K) [application/zip]
# Saving to: ‘SE.zip’
#
# SE.zip              100%[===================>]  82.35K  66.2KB/s    in 1.2s
#
# 2020-08-13 15:16:01 (66.2 KB/s) - ‘SE.zip’ saved [84322/84322]

# %%
# !unzip SE.zip
# Out:
# Archive:  SE.zip
#   inflating: readme.txt
#   inflating: SE.txt

# %% [markdown]
# ### Load zip codes into a data frame

# %%
import pandas as pd
zips = pd.read_csv('SE.txt', header=None, sep='\t')
zips.columns = ['country_code', 'postal_code', 'place_name',
                'admin_name1', 'admin_code1',
                'admin_name2', 'admin_code2',
                'admin_name3', 'admin_code3',
                'latitude', 'longitude',
                'accuracy']
zips
# Out:
#       country_code postal_code   place_name admin_name1 admin_code1  \
# 0               SE      186 00   Vallentuna   Stockholm          AB
# 1               SE      186 01   Vallentuna   Stockholm          AB
# 2               SE      186 03      Brottby   Stockholm          AB
# 3               SE      186 21   Vallentuna   Stockholm          AB
# 4               SE      186 22   Vallentuna   Stockholm          AB
# ...            ...         ...          ...         ...         ...
# 16398           SE      624 66         Fårö         NaN         NaN
# 16399           SE      624 67         Fårö         NaN         NaN
# 16400           SE      734 94   Strömsholm         NaN         NaN
# 16401           SE      749 50     Ekolsund         NaN         NaN
# 16402           SE      772 20  Grängesberg         NaN         NaN
#
#       admin_name2  admin_code2  admin_name3  admin_code3  latitude  longitude  \
# 0      Vallentuna        115.0          NaN          NaN   59.5344    18.0776
# 1      Vallentuna        115.0          NaN          NaN   59.5344    18.0776
# 2      Vallentuna        115.0          NaN          NaN   59.5632    18.2403
# 3      Vallentuna        115.0          NaN          NaN   59.5344    18.0776
# 4      Vallentuna        115.0          NaN          NaN   59.5344    18.0776
# ...           ...          ...          ...          ...       ...        ...
# 16398         NaN          NaN          NaN          NaN   57.9167    19.1333
# 16399         NaN          NaN          NaN          NaN   57.9167    19.1333
# 16400         NaN          NaN          NaN          NaN   59.5333    16.2500
# 16401         NaN          NaN          NaN          NaN   59.6167    17.3667
# 16402         NaN          NaN          NaN          NaN   60.0833    14.9833
#
#        accuracy
# 0           4.0
# 1           4.0
# 2           4.0
# 3           4.0
# 4           4.0
# ...         ...
# 16398       4.0
# 16399       4.0
# 16400       4.0
# 16401       4.0
# 16402       4.0
#
# [16403 rows x 12 columns]

# %% [markdown]
# ### Clean up and filter data frame to include only Stockholm (including suburbs)

# %%
import numpy as np
zips = zips[np.logical_not(zips.admin_name1.isna())]
zips = zips[zips.admin_name1.str.contains('Stockholm')]
zips
# Out:
#      country_code postal_code  place_name admin_name1 admin_code1 admin_name2  \
# 0              SE      186 00  Vallentuna   Stockholm          AB  Vallentuna
# 1              SE      186 01  Vallentuna   Stockholm          AB  Vallentuna
# 2              SE      186 03     Brottby   Stockholm          AB  Vallentuna
# 3              SE      186 21  Vallentuna   Stockholm          AB  Vallentuna
# 4              SE      186 22  Vallentuna   Stockholm          AB  Vallentuna
# ...           ...         ...         ...         ...         ...         ...
# 3443           SE      197 92         Bro   Stockholm          AB         NaN
# 3444           SE      197 93         Bro   Stockholm          AB         NaN
# 3445           SE      761 20   Norrtälje   Stockholm          AB         NaN
# 3446           SE      762 20       Rimbo   Stockholm          AB         NaN
# 3447           SE      763 20  Hallstavik   Stockholm          AB         NaN
#
#       admin_code2  admin_name3  admin_code3  latitude  longitude  accuracy
# 0           115.0          NaN          NaN   59.5344    18.0776       4.0
# 1           115.0          NaN          NaN   59.5344    18.0776       4.0
# 2           115.0          NaN          NaN   59.5632    18.2403       4.0
# 3           115.0          NaN          NaN   59.5344    18.0776       4.0
# 4           115.0          NaN          NaN   59.5344    18.0776       4.0
# ...           ...          ...          ...       ...        ...       ...
# 3443          NaN          NaN          NaN   59.5167    17.6333       4.0
# 3444          NaN          NaN          NaN   59.5167    17.6333       4.0
# 3445          NaN          NaN          NaN   59.7580    18.7050       4.0
# 3446          NaN          NaN          NaN   59.7500    18.3667       4.0
# 3447          NaN          NaN          NaN   60.0500    18.6000       4.0
#
# [3448 rows x 12 columns]

# %%
zips_f = zips[['place_name', 'latitude', 'longitude']]
zips_f
# Out:
#       place_name  latitude  longitude
# 0     Vallentuna   59.5344    18.0776
# 1     Vallentuna   59.5344    18.0776
# 2        Brottby   59.5632    18.2403
# 3     Vallentuna   59.5344    18.0776
# 4     Vallentuna   59.5344    18.0776
# ...          ...       ...        ...
# 3443         Bro   59.5167    17.6333
# 3444         Bro   59.5167    17.6333
# 3445   Norrtälje   59.7580    18.7050
# 3446       Rimbo   59.7500    18.3667
# 3447  Hallstavik   60.0500    18.6000
#
# [3448 rows x 3 columns]

# %% [markdown]
# Some places have the same latitude and longitude, collapse them

# %%
foo = []
for z in zips_f.groupby(['latitude', 'longitude'], axis=0):
    s = ', '.join(z[1].place_name.unique())
    foo.append([s, z[0][0], z[0][1]])

# %%
zips_ff = pd.DataFrame(foo)
zips_ff.columns = ['place_name', 'latitude', 'longitude']

# %%
zips_ff
# Out:
#       place_name  latitude  longitude
# 0      Nynäshamn   58.9034    17.9479
# 1     Stora Vika   58.9333    17.8000
# 2            Utö   58.9667    18.3331
# 3        Sorunda   58.9802    17.9374
# 4          Muskö   58.9831    18.1331
# ..           ...       ...        ...
# 111    Skebobruk   59.9667    18.6000
# 112        Väddö   59.9833    18.8167
# 113   Hallstavik   60.0500    18.6000
# 114  Grisslehamn   60.1000    18.8333
# 115      Herräng   60.1333    18.6500
#
# [116 rows x 3 columns]

# %% [markdown]
# ## Get venues for each place with the Foursquare API

# %%
import requests

CLIENT_ID = 'Z0CIJDN40BWP5SYLHGMIFBKZSVR3DS30HUAB2FE1XK0F5GVH'
CLIENT_SECRET = 'M2TPZIYIRHS55FPPHMPMSZZU0C1QOJJELLMTAU5H1I5LLVVH'
VERSION = '20180605' # Foursquare API version
LIMIT = 50000 # limit of number of venues returned
radius = 1000

venues_list=[]
for name, lat, lng in zip(zips_ff.place_name,
                          zips_ff.latitude, zips_ff.longitude):
    print(name,lat,lng)
    
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        radius, 
        LIMIT)
    results = requests.get(url).json()["response"]['groups'][0]['items']
    venues_list.append([(
        name, 
        lat, 
        lng, 
        v['venue']['name'], 
        v['venue']['location']['lat'], 
        v['venue']['location']['lng'],  
        v['venue']['categories'][0]['name']) for v in results])
# Out:
# Nynäshamn 58.9034 17.9479
# Stora Vika 58.9333 17.8
# Utö 58.9667 18.3331
# Sorunda 58.9802 17.9374
# Muskö 58.9831 18.1331
# Sorunda 58.9832 17.9777
# Ösmo, Sorunda 58.9833 17.9
# Hölö 59.0167 17.5333
# Mölnbo, Enhörna 59.05 17.4167
# Ornö 59.0544 18.4283
# Järna 59.1 17.5667
# Tungelsta 59.1 18.0331
# Västerhaninge 59.1167 18.1
# Dalarö 59.1331 18.4064
# Hässelby 59.15 16.85
# Haninge 59.1677 18.1448
# Nykvarn 59.1833 17.4333
# Nämdö 59.1833 18.6833
# Södertälje 59.1955 17.6252
# Tumba, Grödinge 59.1986 17.8332
# Grödinge 59.1988 17.829
# Rönninge 59.2 17.7333
# Uttran 59.2 17.8
# Tullinge 59.2 17.8833
# Skogås 59.2167 18.15
# Trångsund 59.2333 18.1333
# Tyresö 59.2333 18.3
# Huddinge, Kungens Kurva 59.236999999999995 17.9819
# Norsborg 59.25 17.7833
# Farsta 59.25 18.0833
# Sköndal 59.25 18.1167
# Bagarmossen 59.2556 18.1167
# Bagarmossen 59.26 18.1167
# Hårsfjärden 59.2654 18.64
# Vårby 59.2667 17.8833
# Skarpnäck 59.2667 18.1167
# Älta 59.2667 18.1833
# Skärholmen 59.2755 17.902
# Älvsjö 59.2793 18.0111
# Segeltorp, Kungens Kurva 59.2833 17.9333
# Enskede 59.2833 18.0667
# Saltsjöbaden 59.2833 18.3
# Stavsnäs 59.2833 18.6833
# Sandhamn 59.2833 18.9167
# Ekerö 59.291000000000004 17.8121
# Bandhagen 59.2968 18.0313
# Årsta, Enskede Gård 59.3 18.05
# Saltsjö-Duvnäs 59.3 18.2
# Djurhamn 59.3 18.6833
# Hägersten 59.3059 17.9872
# Munsö, Adelsö 59.3081 17.85
# Nacka 59.3105 18.1637
# Nacka Strand 59.3134 18.1481
# Nacka Strand 59.3137 18.1496
# Saltsjö-Boo 59.3173 18.255
# Nacka Strand 59.3179 18.1308
# Runmarö 59.3196 18.7213
# Nacka Strand 59.3216 18.1143
# Drottningholm 59.3251 17.8878
# Gustavsberg, Ingarö 59.3268 18.3898
# Stockholm, Tomteboda 59.3326 18.0649
# Stockholm-Globen 59.3332 18.0525
# Stenhamra 59.3333 17.6667
# Skå 59.3333 17.7333
# Johanneshov, Enskededalen, Stockholm-Globen 59.3333 18.05
# Tomteboda, Stockholm 59.3355 18.0582
# Stavsudda 59.3499 18.7582
# Färentuna 59.35 17.7
# Bromma 59.35 17.9167
# Värmdö 59.35 18.5
# Järfälla 59.3501 17.9658
# Solna 59.36 18.0009
# Sundbyberg 59.3613 17.9711
# Vällingby 59.3644 17.8741
# Svartsjö, Färentuna 59.3667 17.7333
# Lidingö 59.3667 18.1333
# Spånga 59.3833 17.9167
# Stocksund 59.3833 18.0667
# Danderyd 59.3987 18.0294
# Djursholm 59.3993 18.0562
# Möja 59.3997 18.8331
# Gällnöby 59.4 18.6333
# Vaxholm 59.4022 18.3532
# Kista 59.4032 17.9448
# Sollentuna 59.428000000000004 17.9509
# Enebyberg 59.4333 18.05
# Täby 59.4439 18.0687
# Skälvik 59.4481 18.69
# Österskär 59.4671 18.3062
# Ingmarsö 59.4675 18.7494
# Kungsängen 59.4786 17.7483
# Åkersberga 59.4794 18.2997
# Bro 59.5167 17.6333
# Upplands Väsby 59.5204 17.9083
# Ljusterö 59.5275 18.6211
# Vallentuna 59.5344 18.0776
# Brottby 59.5632 18.2403
# Rosersberg 59.5833 17.8833
# Blidö 59.615 18.8917
# Märsta 59.6167 17.85
# Sigtuna 59.6173 17.7236
# Bergshamra 59.6347 18.6281
# Furusund 59.6664 18.9225
# Yxlan 59.6707 18.8689
# Rimbo 59.75 18.3667
# Björkö 59.75 19.0
# Norrtälje 59.758 18.705
# Gräddö 59.7667 19.0333
# Vätö 59.8167 18.9167
# Arholma 59.85 19.1
# Barnens Ö 59.9633 18.88
# Skebobruk 59.9667 18.6
# Väddö 59.9833 18.8167
# Hallstavik 60.05 18.6
# Grisslehamn 60.1 18.8333
# Herräng 60.1333 18.65

# %%
nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
nearby_venues.columns = ['place_name', 
              'latitude', 
              'longitude', 
              'venue', 
              'venue_latitude', 
              'venue_longitude', 
              'venue_category']
nearby_venues
# Out:
#        place_name  latitude  longitude              venue  venue_latitude  \
# 0       Nynäshamn   58.9034    17.9479  Nynäshamns Rökeri       58.900889
# 1       Nynäshamn   58.9034    17.9479             Kroken       58.900443
# 2       Nynäshamn   58.9034    17.9479      Nynäshamn (J)       58.901110
# 3       Nynäshamn   58.9034    17.9479  Skärgårdshotellet       58.903910
# 4       Nynäshamn   58.9034    17.9479  Lejonet & Björnen       58.901096
# ...           ...       ...        ...                ...             ...
# 1801  Grisslehamn   60.1000    18.8333         M/S Eckerö       60.098381
# 1802      Herräng   60.1333    18.6500   Ice Cream Parlor       60.128384
# 1803      Herräng   60.1333    18.6500     Herräng Marina       60.137839
# 1804      Herräng   60.1333    18.6500             Kuggen       60.130106
# 1805      Herräng   60.1333    18.6500     Lindy Hop Shop       60.127952
#
#       venue_longitude           venue_category
# 0           17.952507       Seafood Restaurant
# 1           17.951698  Scandinavian Restaurant
# 2           17.951617            Train Station
# 3           17.953573                    Hotel
# 4           17.952004           Ice Cream Shop
# ...               ...                      ...
# 1801        18.815999            Boat or Ferry
# 1802        18.649281           Ice Cream Shop
# 1803        18.643511          Harbor / Marina
# 1804        18.647298        Convenience Store
# 1805        18.643961   Thrift / Vintage Store
#
# [1806 rows x 7 columns]

# %% [markdown]
# ## Filter the results to get restaurants

# %%
import re
foodplaces = nearby_venues[nearby_venues.venue_category.str.contains('restaurant', flags=re.IGNORECASE, regex=True)]
foodplaces
# Out:
#        place_name  latitude  longitude               venue  venue_latitude  \
# 0       Nynäshamn   58.9034    17.9479   Nynäshamns Rökeri       58.900889
# 1       Nynäshamn   58.9034    17.9479              Kroken       58.900443
# 5       Nynäshamn   58.9034    17.9479    Restaurang Lydia       58.902202
# 12      Nynäshamn   58.9034    17.9479  Nynäshamns Grillen       58.901492
# 21      Nynäshamn   58.9034    17.9479               Freja       58.899600
# ...           ...       ...        ...                 ...             ...
# 1738      Sigtuna   59.6173    17.7236        32 Rum o Kök       59.614162
# 1742     Furusund   59.6664    18.9225          El Capitan       59.661901
# 1746     Furusund   59.6664    18.9225    Köpmanholm Kiosk       59.659494
# 1757    Norrtälje   59.7580    18.7050            Ett Glas       59.757124
# 1800  Grisslehamn   60.1000    18.8333         thaikiosken       60.100585
#
#       venue_longitude           venue_category
# 0           17.952507       Seafood Restaurant
# 1           17.951698  Scandinavian Restaurant
# 5           17.949296  Scandinavian Restaurant
# 12          17.951024     Fast Food Restaurant
# 21          17.951011  Scandinavian Restaurant
# ...               ...                      ...
# 1738        17.712898  Scandinavian Restaurant
# 1742        18.929215               Restaurant
# 1746        18.931508     Fast Food Restaurant
# 1757        18.703121               Restaurant
# 1800        18.816457         Asian Restaurant
#
# [353 rows x 7 columns]

# %% [markdown]
# Most common restaurant types

# %%
foodplaces.venue_category.value_counts()
# Out:
# Scandinavian Restaurant          67
# Restaurant                       39
# Fast Food Restaurant             29
# Sushi Restaurant                 27
# Asian Restaurant                 23
# Italian Restaurant               20
# Middle Eastern Restaurant        18
# Indian Restaurant                18
# Thai Restaurant                  16
# Modern European Restaurant       10
# Vietnamese Restaurant             9
# Seafood Restaurant                8
# American Restaurant               8
# Greek Restaurant                  8
# Chinese Restaurant                7
# Japanese Restaurant               6
# Tapas Restaurant                  6
# French Restaurant                 5
# Falafel Restaurant                4
# Mexican Restaurant                3
# Kebab Restaurant                  3
# Korean Restaurant                 3
# South American Restaurant         3
# Ramen Restaurant                  3
# Vegetarian / Vegan Restaurant     2
# Szechuan Restaurant               2
# New American Restaurant           1
# Indonesian Restaurant             1
# Hawaiian Restaurant               1
# Theme Restaurant                  1
# South Indian Restaurant           1
# Persian Restaurant                1
# Name: venue_category, dtype: int64

# %%
pizza = nearby_venues[nearby_venues.venue_category.str.contains('pizza', flags=re.IGNORECASE, regex=True)]
pizza
# Out:
#            place_name  latitude  longitude                     venue  \
# 42               Hölö   59.0167    17.5333  Pizzeria Restaurang Hölö
# 45    Mölnbo, Enhörna   59.0500    17.4167          Abbes Restaurang
# 56          Tungelsta   59.1000    18.0331     Vaskós Pub & Pizzeria
# 155          Grödinge   59.1988    17.8290        Robbans Pizzabutik
# 183          Tullinge   59.2000    17.8833                  La Serra
# ...               ...       ...        ...                       ...
# 1695          Brottby   59.5632    18.2403              Brottby Cafe
# 1697          Brottby   59.5632    18.2403    Karby Grill & Pizzeria
# 1719           Märsta   59.6167    17.8500                  Castello
# 1767        Norrtälje   59.7580    18.7050       Esplanaden Pizzeria
# 1797       Hallstavik   60.0500    18.6000                Blå Krogen
#
#       venue_latitude  venue_longitude venue_category
# 42         59.025128        17.535102    Pizza Place
# 45         59.047477        17.419667    Pizza Place
# 56         59.102815        18.043968    Pizza Place
# 155        59.190786        17.822716    Pizza Place
# 183        59.201730        17.891121    Pizza Place
# ...              ...              ...            ...
# 1695       59.561397        18.239000    Pizza Place
# 1697       59.560201        18.226619    Pizza Place
# 1719       59.623420        17.857867    Pizza Place
# 1767       59.756805        18.688813    Pizza Place
# 1797       60.057912        18.595779    Pizza Place
#
# [73 rows x 7 columns]

# %% [markdown]
# ## Generate a map of the identified pizza venues

# %%
import folium

# %%
map = folium.Map(location=[59.3257, 18.0719], zoom_start=8)

# %%
# add markers to map
for lat, lng, place_name, venue in zip(pizza['latitude'], pizza['longitude'], pizza['place_name'], pizza['venue']):
    label = '{}, {}'.format(place_name, venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Identify locations without a pizza place

# %%
wo_pizza = zips_ff[np.logical_not(zips_ff.place_name.isin(pizza.place_name))]
wo_pizza
# Out:
#       place_name  latitude  longitude
# 0      Nynäshamn   58.9034    17.9479
# 1     Stora Vika   58.9333    17.8000
# 2            Utö   58.9667    18.3331
# 3        Sorunda   58.9802    17.9374
# 4          Muskö   58.9831    18.1331
# ..           ...       ...        ...
# 110    Barnens Ö   59.9633    18.8800
# 111    Skebobruk   59.9667    18.6000
# 112        Väddö   59.9833    18.8167
# 114  Grisslehamn   60.1000    18.8333
# 115      Herräng   60.1333    18.6500
#
# [73 rows x 3 columns]

# %% [markdown]
# ## Plot locations without a pizza place on the map

# %%
map2 = folium.Map(location=[59.3257, 18.0719], zoom_start=8)

# %%
# add markers to map
for lat, lng, place_name in zip(wo_pizza['latitude'],
                                wo_pizza['longitude'],
                                wo_pizza['place_name']):
    label = '{}'.format(place_name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map2)
    
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
